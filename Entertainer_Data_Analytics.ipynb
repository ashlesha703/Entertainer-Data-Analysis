# %% [markdown]
# <a href="https://colab.research.google.com/github/ashlesha703/Entertainer-Data-Analysis/blob/main/Entertainer_Data_Analytics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# **BASIC INFORMATION OF ENTERTAINMENT**

# %%
import pandas as pd

# Load the Excel file into a pandas DataFrame
excel_file = pd.read_excel('/Entertainer - Basic Info.xlsx')

# Save the DataFrame to a CSV file
excel_file.to_csv('Basic Info.csv', index=False)

print('Conversion complete.')
# Out:
# Conversion complete.

# %%
filepath = '/content/Basic Info.csv'

# %%
data = pd.read_csv(filepath)

# %%
data.head()
# Out:
#        Entertainer Gender (traditional)  Birth Year
# 0            Adele                    F        1988
# 1   Angelina Jolie                    F        1975
# 2  Aretha Franklin                    F        1942
# 3      Bette Davis                    F        1908
# 4      Betty White                    F        1922

# %%
data
# Out:
#         Entertainer Gender (traditional)  Birth Year
# 0             Adele                    F        1988
# 1    Angelina Jolie                    F        1975
# 2   Aretha Franklin                    F        1942
# 3       Bette Davis                    F        1908
# 4       Betty White                    F        1922
# ..              ...                  ...         ...
# 65        Tom Hanks                    M        1956
# 66     Tony Bennett                    M        1926
# 67     Wayne Newton                    M        1942
# 68       Will Smith                    M        1968
# 69    Willie Nelson                    M        1933
#
# [70 rows x 3 columns]

# %%
data.shape
# Out:
# (70, 3)

# %%
data.dtypes
# Out:
# Entertainer             object
# Gender (traditional)    object
# Birth Year               int64
# dtype: object

# %%
data.size
# Out:
# 210

# %%
data.isnull()
# Out:
#     Entertainer  Gender (traditional)  Birth Year
# 0         False                 False       False
# 1         False                 False       False
# 2         False                 False       False
# 3         False                 False       False
# 4         False                 False       False
# ..          ...                   ...         ...
# 65        False                 False       False
# 66        False                 False       False
# 67        False                 False       False
# 68        False                 False       False
# 69        False                 False       False
#
# [70 rows x 3 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70 entries, 0 to 69
# Data columns (total 3 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Entertainer           70 non-null     object
#  1   Gender (traditional)  70 non-null     object
#  2   Birth Year            70 non-null     int64
# dtypes: int64(1), object(2)
# memory usage: 1.8+ KB

# %%
data['Entertainer'].describe()
# Out:
# count        70
# unique       70
# top       Adele
# freq          1
# Name: Entertainer, dtype: object

# %%
count_Adele =len(data['Entertainer'][data['Entertainer'] =='Adele'])
count_Bob =len(data['Entertainer'][data['Entertainer'] =='Bob'])

# %%
print("As per dataset, we have %d records Entertainer as 'Adele'and %d as 'Bob'" %(count_Adele,count_Bob))
# Out:
# As per dataset, we have 1 records Entertainer as 'Adele'and 0 as 'Bob'

# %%
data.describe()
# Out:
#         Birth Year
# count    70.000000
# mean   1935.585714
# std      24.135783
# min    1889.000000
# 25%    1916.000000
# 50%    1935.500000
# 75%    1954.000000
# max    1988.000000

# %%
data = data[data['Entertainer'] != 'Adele']

# %%
data[data['Entertainer'] == 'Adele'].mean()
# Out:
# Entertainer             NaN
# Gender (traditional)    NaN
# Birth Year              NaN
# dtype: object

# %%
import pandas as pd

# Load the Excel file into a pandas DataFrame
excel_file = pd.read_excel('/content/Entertainer - Breakthrough Info.xlsx')

# Save the DataFrame to a CSV file
excel_file.to_csv('Breakthrough Info.csv', index=False)

print('Conversion complete.')
# Out:
# Conversion complete.

# %% [markdown]
# **FOR BREAKTHROUGH INFORMATION OF ENTERTAINMENT**

# %%
import plotly.express as px
df = pd.read_csv("/content/Breakthrough Info.csv")

# %%
df.shape
# Out:
# (70, 4)

# %%
df.columns
# Out:
# Index(['Entertainer', 'Year of Breakthrough/#1 Hit/Award Nomination',
#        'Breakthrough Name', 'Year of First Oscar/Grammy/Emmy'],
#       dtype='object')

# %%
x = df.groupby(['Breakthrough Name']).size().reset_index(name = 'counts')
print(x)
# Out:
#                 Breakthrough Name  counts
# 0   (I Can't Get No) Satisfaction       1
# 1                              19       1
# 2                  21 Jump Street       1
# 3                              24       1
# 4                   Anna Christie       1
# ..                            ...     ...
# 64              Toast of the Town       1
# 65              Twentieth Century       1
# 66    Wake Me Up Before You Go-Go       1
# 67                West Side Story       1
# 68     You Can't Take it With You       1
#
# [69 rows x 2 columns]

# %%
pieChart = px.pie(x, values='counts' , names='Breakthrough Name' , title='Several Songs')
pieChart.show

# %%
import plotly.graph_objects as go

# Create a simple scatter plot
fig = go.Figure(data=go.Scatter(x=[1, 2, 3], y=[4, 1, 3]))

# Display the figure
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="2ade37a5-24c0-4e38-a589-f2369ca56d36" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2ade37a5-24c0-4e38-a589-f2369ca56d36")) {                    Plotly.newPlot(                        "2ade37a5-24c0-4e38-a589-f2369ca56d36",                        [{"x":[1,2,3],"y":[4,1,3],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"scattergl":[{"type":"scattergl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatter3d":[{"type":"scatter3d","line": ...

# %%
df['Year of First Oscar/Grammy/Emmy'] = df['Year of First Oscar/Grammy/Emmy'].fillna('Year of First Oscar/Grammy/Emmy not specified')
df.head()
# Out:
#        Entertainer  Year of Breakthrough/#1 Hit/Award Nomination  \
# 0            Adele                                          2008
# 1   Angelina Jolie                                          1999
# 2  Aretha Franklin                                          1967
# 3      Bette Davis                                          1934
# 4      Betty White                                          1952
#
#                           Breakthrough Name Year of First Oscar/Grammy/Emmy
# 0                                        19                          2009.0
# 1                         Girl, Interrupted                          1999.0
# 2  I Never Loved a Man (The Way I Love You)                          1968.0
# 3                          Of Human Bondage                          1935.0
# 4                      Life with Elilzabeth                          1976.0

# %%
Entertainer_list = pd.DataFrame()
print(Entertainer_list)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
Entertainer_list = df.Entertainer.str.split(',', expand=True).stack()
print(Entertainer_list)
# Out:
# 0   0              Adele
# 1   0     Angelina Jolie
# 2   0    Aretha Franklin
# 3   0        Bette Davis
# 4   0        Betty White
#               ...
# 65  0          Tom Hanks
# 66  0       Tony Bennett
# 67  0       Wayne Newton
# 68  0         Will Smith
# 69  0      Willie Nelson
# Length: 70, dtype: object

# %%
Entertainer_list = Entertainer_list.to_frame()
print(Entertainer_list)
# Out:
#                     0
# 0  0            Adele
# 1  0   Angelina Jolie
# 2  0  Aretha Franklin
# 3  0      Bette Davis
# 4  0      Betty White
# ...               ...
# 65 0        Tom Hanks
# 66 0     Tony Bennett
# 67 0     Wayne Newton
# 68 0       Will Smith
# 69 0    Willie Nelson
#
# [70 rows x 1 columns]

# %% [markdown]
# **Last Work Information For Entertainment**

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import plotly.express as px

# Load the Excel file into a pandas DataFrame
excel_file = pd.read_excel('/content/Entertainer - Last work Info.xlsx')

# Save the DataFrame to a CSV file
excel_file.to_csv('Last work.csv', index=False)

print('Conversion complete.')
# Out:
# Conversion complete.

# %%
filepath = '/content/Last work.csv'

# %%
df.columns
# Out:
# Index(['Entertainer', 'Year of Breakthrough/#1 Hit/Award Nomination',
#        'Breakthrough Name', 'Year of First Oscar/Grammy/Emmy'],
#       dtype='object')

# %%
df.head()
# Out:
#        Entertainer  Year of Breakthrough/#1 Hit/Award Nomination  \
# 0            Adele                                          2008
# 1   Angelina Jolie                                          1999
# 2  Aretha Franklin                                          1967
# 3      Bette Davis                                          1934
# 4      Betty White                                          1952
#
#                           Breakthrough Name Year of First Oscar/Grammy/Emmy
# 0                                        19                          2009.0
# 1                         Girl, Interrupted                          1999.0
# 2  I Never Loved a Man (The Way I Love You)                          1968.0
# 3                          Of Human Bondage                          1935.0
# 4                      Life with Elilzabeth                          1976.0

# %%
plt.figure(figsize =(10, 6))
df.groupby('Year of Breakthrough/#1 Hit/Award Nomination')

# %%
df['Year of First Oscar/Grammy/Emmy'].dtype
df['Year of Breakthrough/#1 Hit/Award Nomination'].dtype
# Out:
# dtype('int64')

# %%
df['Year of First Oscar/Grammy/Emmy'] = pd.to_numeric(df['Year of First Oscar/Grammy/Emmy'], errors='coerce')
df['Year of Breakthrough/#1 Hit/Award Nomination'] = pd.to_numeric(df['Year of Breakthrough/#1 Hit/Award Nomination'], errors='coerce')

# %%
df.insert(3, 'Best year' , df['Year of First Oscar/Grammy/Emmy'] - df['Year of Breakthrough/#1 Hit/Award Nomination'])

# %%
df['Best year'].dtype
# Out:
# dtype('float64')

# %%
df['Best year'].plot(kind='hist', bins=10)
plt.xlabel('Years')
plt.ylabel('Frequency')
plt.title('Distribution of Best Year')
plt.show()

# %%
df1 = df[['Entertainer','Year of Breakthrough/#1 Hit/Award Nomination','Breakthrough Name','Year of First Oscar/Grammy/Emmy']]

# %%
df1.hist(bins = 20, figsize =(14,12))
# Out:
# array([[<Axes: title={'center': 'Year of Breakthrough/#1 Hit/Award Nomination'}>,
#         <Axes: title={'center': 'Year of First Oscar/Grammy/Emmy'}>]],
#       dtype=object)

# %%
df.Entertainer.value_counts()
# Out:
# Entertainer
# Adele               1
# Kirk Douglas        1
# Mariah Carey        1
# Madonna             1
# Louis Armstrong     1
#                    ..
# Humphrey Bogart     1
# James Dean          1
# Jay Leno            1
# Jennifer Aniston    1
# Willie Nelson       1
# Name: count, Length: 70, dtype: int64

# %%
import pandas as pd

# Access the Breakthrough Name column:
df["Breakthrough Name"]

# Apply the max() function to the Breakthrough Name column:
df["Breakthrough Name"].max()
# Out:
# "You Can't Take it With You"

# %%
import pandas as pd

# Access the Year of First Oscar/Grammy/Emmy column:
df["Year of First Oscar/Grammy/Emmy"]

# Apply the max() function to the Year of First Oscar/Grammy/Emmy column:
df["Year of First Oscar/Grammy/Emmy"].max()

# Access the Year of Breakthrough/#1 Hit/Award Nomination column:
df["Year of Breakthrough/#1 Hit/Award Nomination"]

# Apply the max() function to the Year of Breakthrough/#1 Hit/Award Nomination column:
df["Year of Breakthrough/#1 Hit/Award Nomination"].max()
# Out:
# 2008

# %%
import pandas as pd

# Sort the DataFrame by multiple columns in ascending order:
df.sort_values(by=["Year of First Oscar/Grammy/Emmy", "Year of Breakthrough/#1 Hit/Award Nomination"], ascending=True)
# Out:
#           Entertainer  Year of Breakthrough/#1 Hit/Award Nomination  \
# 11    Charlie Chaplin                                          1915
# 42  Katherine Hepburn                                          1933
# 13        Clark Gable                                          1934
# 3         Bette Davis                                          1934
# 6            Bob Hope                                          1938
# ..                ...                                           ...
# 8      Carole Lombard                                          1934
# 15    Debbie Reynolds                                          1952
# 67       Wayne Newton                                          1972
# 9       Carrie Fisher                                          1977
# 40        Johnny Depp                                          1987
#
#                 Breakthrough Name  Best year  Year of First Oscar/Grammy/Emmy
# 11                      The Tramp       14.0                           1929.0
# 42                  Morning Glory        0.0                           1933.0
# 13          It Happened One Night        0.0                           1934.0
# 3                Of Human Bondage        1.0                           1935.0
# 6       The Big Broadcast of 1938        2.0                           1940.0
# ..                            ...        ...                              ...
# 8               Twentieth Century        NaN                              NaN
# 15            Singin' in the Rain        NaN                              NaN
# 67  Daddy, Don't You Walk So Fast        NaN                              NaN
# 9                       Star Wars        NaN                              NaN
# 40                 21 Jump Street        NaN                              NaN
#
# [70 rows x 5 columns]

# %%
df2 = df.groupby('Year of Breakthrough/#1 Hit/Award Nomination')['Year of First Oscar/Grammy/Emmy'].sum().plot(kind = 'line')
